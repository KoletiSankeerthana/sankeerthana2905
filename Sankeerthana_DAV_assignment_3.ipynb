# %% [markdown]
# Anjaneyulu_DAV_Assignment_3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_frame1=pd.read_csv("C:\\Users\\saipa\\Downloads\\amazondataset\\Amzon job reviews (USA  India) 2008-2020.csv")
data_frame1
# Out:
#        ID number         Date                   Location  \
# 0              1  22 Apr 2008              Palo Alto, CA
# 1              2  23 Apr 2008              Lexington, KY
# 2              3   2 May 2008                Seattle, WA
# 3              4  23 May 2008                Seattle, WA
# 4              5  25 May 2008                Seattle, WA
# ...          ...          ...                        ...
# 29489      29490  30 Dec 2020                  Hyderābād
# 29490      29491  31 Dec 2020  Gurgaon, Haryana, Haryana
# 29491      29492  31 Dec 2020                    Chennai
# 29492      29493  31 Dec 2020                     Mumbai
# 29493      29494  31 Dec 2020                  Hyderābād
#
#                                             Position  \
# 0                                     Sales Director
# 1                              Systems Administrator
# 2                                   Technical Writer
# 3                           Software Design Engineer
# ...

# %%
data_frame1.shape  # no.of rows and columns
# Out:
# (29494, 22)

# %%
data_frame1.info() # summary information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29494 entries, 0 to 29493
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID number                  29494 non-null  int64
#  1   Date                       29494 non-null  object
#  2   Location                   29441 non-null  object
#  3   Position                   28986 non-null  object
#  4   Comment for company        29424 non-null  object
#  5   Overall ratting            29494 non-null  float64
#  6   Work/Life Balance          26691 non-null  float64
#  7   Culture & Values           25819 non-null  float64
#  8   Diversity & Inclusion      3821 non-null   float64
#  9   Career Opportunities       26717 non-null  float64
#  10  Compensation and Benefits  26706 non-null  float64
#  11  Senior Management          26366 non-null  float64
#  12  CEO Approval               22948 non-null  object
# ...

# %%
p=data_frame1.head() # first five rows of the data
p
# Out:
#    ID         Date       Location                  Job Title  \
# 0   1  22 Apr 2008  Palo Alto, CA             Sales Director
# 1   2  23 Apr 2008  Lexington, KY      Systems Administrator
# 2   3   2 May 2008    Seattle, WA           Technical Writer
# 3   4  23 May 2008    Seattle, WA   Software Design Engineer
# 4   5  25 May 2008    Seattle, WA   Senior Marketing Manager
#
#                                 Comment for company   Overall Rating  \
# 0  Amazon isn't all it's cracked up to be, unless...             2.0
# 1                            Long hours and low pay.             2.0
# 2       A fair website, but sucks as a place to work             2.0
# 3  About what you'd expect when you sell your sou...             3.0
# 4      I can't believe I get paid to do what I love!             4.0
#
#    Work Life Balance  Culture and Values  Diversity and Inclusion  \
# 0                1.5                 NaN                      NaN
# ...

# %%
p=data_frame1.tail() # last five rows of the dataset
p
# Out:
#        ID number         Date                   Location  \
# 29489      29490  30 Dec 2020                  Hyderābād
# 29490      29491  31 Dec 2020  Gurgaon, Haryana, Haryana
# 29491      29492  31 Dec 2020                    Chennai
# 29492      29493  31 Dec 2020                     Mumbai
# 29493      29494  31 Dec 2020                  Hyderābād
#
#                                             Position  \
# 29489                                      Associate
# 29490   Software Development Engineer In Test (SDET)
# 29491                                Quality Analyst
# 29492                            Real Estate Manager
# 29493                     Customer Service Associate
#
#                                 Comment for company   Overall ratting  \
# 29489                                     No reviews              4.0
# 29490  Best infrastructure and hospitality by Amazon              5.0
# 29491                            Great place to work              4.0
# ...

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         5 non-null      int64
#  1   Date                       5 non-null      object
#  2   Location                   5 non-null      object
#  3   Job Title                  5 non-null      object
#  4   Comment for company        5 non-null      object
#  5   Overall Rating             5 non-null      float64
#  6   Work Life Balance          5 non-null      float64
#  7   Culture and Values         0 non-null      float64
#  8   Diversity and Inclusion    0 non-null      float64
#  9   Career Opportunities       5 non-null      float64
#  10  Compensation and Benefits  5 non-null      float64
#  11  Senior Management          5 non-null      float64
#  12  CEO Approval               5 non-null      object
# ...

# %%
q=p.isnull().sum() # the sum of nulls of the columns
q
# Out:
# ID number                    0
# Date                         0
# Location                     0
# Position                     0
# Comment for company          0
# Overall ratting              0
# Work/Life Balance            2
# Culture & Values             1
# Diversity & Inclusion        3
# Career Opportunities         1
# Compensation and Benefits    1
# Senior Management            2
# CEO Approval                 4
# Recommended                  2
# Business Outlook             4
# Current employee             0
# Former employee              0
# Timeline                     1
# cons                         0
# pros                         0
# advice to Management         4
# review_url                   0
# dtype: int64

# %%
import numpy as np

# %%
mean=data_frame_1['Overall ratting'].mean(skipna=True) # mean of overallrating
print(mean)
r=p.fillna(mean) # fills null values with overall rating mean
# Out:
# 3.712958567844307
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 mean=df1['Overall ratting'].mean(skipna=True) # mean of overallrating
#       2 print(mean)
# ----> 3 r=p.fillna(mean) # fills null values with overall rating mean
#
# NameError: name 'p' is not defined

# %%
s=data_frame_1.fillna(mean) # Fills NaN values in df1 with the mean of each column
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s=data_frame_1.fillna(mean) # Fills NaN values in df1 with the mean of each column
#       2 s
#
# NameError: name 'data_frame_1' is not defined

# %%
s.isnull().sum()  # columnwise sum of null values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s.isnull().sum()  # columnwise sum of null values
#
# NameError: name 's' is not defined

# %%
t=data_frame_1.describe() # gives the statastical data from df1
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 e=data_frame_1.describe() # gives the statastical data from df1
#       2 e
#
# NameError: name 'data_frame_1' is not defined

# %%
import seaborn as sns

# %%
# To plot the distribution of overall ratings
plt.figure(figsize=(10, 6))
data_frame_1['Overall ratting'].value_counts().sort_index().plot(kind='bar', color='purple')
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Overall Ratings')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # To plot the distribution of overall ratings
#       2 plt.figure(figsize=(10, 6))
# ----> 3 data_frame_1['Overall ratting'].value_counts().sort_index().plot(kind='bar', color='purple')
#       4 plt.xlabel('Overall Rating')
#       5 plt.ylabel('Frequency')
#
# NameError: name 'data_frame_1' is not defined

# %%
# proportion of each overall rating
rating_counts = df1['Overall ratting'].value_counts()
plt.figure(figsize=(10, 8))#pie chart
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.3f%%', colors=plt.cm.Paired.colors)
plt.title('Proportion of Overall Ratings')
plt.axis('equal')  # The equal aspect ratio ensures the pie chart is circular.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\saipa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Overall ratting'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 2
# ...

# %%
# Scatter plot of Work/Life Balance vs. Overall Rating
plt.figure(figsize=(10, 6))
plt.scatter(df1['Work/Life Balance'], df1['Overall ratting'], alpha=0.3, color='purple')
plt.xlabel('Work/Life Balance')
plt.ylabel('Overall Rating')
plt.title('Work/Life Balance vs. Overall Rating')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\saipa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Work/Life Balance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 3
# ...

# %%
#changing the colounm names for better readability 
# Rename the columns names to make them more understandable
df1.rename(columns={
    'ID number': 'ID',
    'Overall ratting': 'Overall Rating',
    'cons': 'Cons',
    'pros': 'Pros',
    'advice to Management': 'Advice to Management',
    'review_url': 'Review URL',
    'Comment for company': 'Comment for Company',
    'CEO Approval': 'CEO Approval',
    'Current employee': 'Current Employee',
    'Former employee': 'Former Employee',
    'Business Outlook': 'Business Outlook',
    'Career Opportunities': 'Career Opportunities',
    'Culture & Values': 'Culture and Values',
    'Diversity & Inclusion': 'Diversity and Inclusion',
    'Work/Life Balance': 'Work Life Balance',
    'Position': 'Job Title'
}, inplace=True)

df1.head()
# Out:
#    ID         Date       Location                  Job Title  \
# 0   1  22 Apr 2008  Palo Alto, CA             Sales Director
# 1   2  23 Apr 2008  Lexington, KY      Systems Administrator
# 2   3   2 May 2008    Seattle, WA           Technical Writer
# 3   4  23 May 2008    Seattle, WA   Software Design Engineer
# 4   5  25 May 2008    Seattle, WA   Senior Marketing Manager
#
#                                 Comment for company   Overall Rating  \
# 0  Amazon isn't all it's cracked up to be, unless...             2.0
# 1                            Long hours and low pay.             2.0
# 2       A fair website, but sucks as a place to work             2.0
# 3  About what you'd expect when you sell your sou...             3.0
# 4      I can't believe I get paid to do what I love!             4.0
#
#    Work Life Balance  Culture and Values  Diversity and Inclusion  \
# 0                1.5                 NaN                      NaN
# ...

# %%
import seaborn as sns

# %%
#Convert 'Work Life Balance' and other columns to numeric (if needed)
numeric_columns = ['Overall Rating', 'Work Life Balance', 'Career Opportunities']
# Handle missing values (e.g., fill NaN with 0 or mean)
df1[numeric_columns] = df1[numeric_columns].fillna(0)
# Calculate correlation matrix
corl_matrix = df1[numeric_columns].corr()
print("Correlation Matrix:")
print(corl_matrix)
# Optional: Visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corl_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:
#                       Overall Rating  Work Life Balance  Career Opportunities
# Overall Rating              1.000000           0.499470              0.514572
# Work Life Balance           0.499470           1.000000              0.668527
# Career Opportunities        0.514572           0.668527              1.000000

# %% [markdown]
# Water_dataset

# %%
df2=pd.read_csv("C:\\Users\\saipa\\Downloads\\waterdataset.csv")
df2
# Out:
#             State Name      District Name      Block Name     Panchayat Name  \
# 0       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)      GOKAVARAM(04)
# 1       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)      GOKAVARAM(04)
# 2       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GAJJANAPUDI(06)
# 3       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GAJJANAPUDI(06)
# 4       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)     CHINTALURU(10)
# ...                ...                ...             ...                ...
# 550237           ASSAM             JORHAT       KALIAPANI     CHINTAMONIGARH
# 550238           ASSAM             JORHAT       KALIAPANI     CHINTAMONIGARH
# 550239           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
# 550240           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
# 550241           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
#
# ...

# %%
df2.shape
# Out:
# (550242, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550242 entries, 0 to 550241
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   State Name         550242 non-null  object
#  1   District Name      550242 non-null  object
#  2   Block Name         550242 non-null  object
#  3   Panchayat Name     550242 non-null  object
#  4   Village Name       550242 non-null  object
#  5   Habitation Name    550240 non-null  object
#  6   Quality Parameter  550237 non-null  object
#  7   Year               550213 non-null  object
# dtypes: object(8)
# memory usage: 33.6+ MB

# %%
p=df2.isnull().sum() 
p
# Out:
# State Name            0
# District Name         0
# Block Name            0
# Panchayat Name        0
# Village Name          0
# Habitation Name       2
# Quality Parameter     5
# Year                 29
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 36

# %%
q=df2.fillna("empty")  
q
# Out:
#             State Name      District Name      Block Name     Panchayat Name  \
# 0       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)      GOKAVARAM(04)
# 1       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)      GOKAVARAM(04)
# 2       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GAJJANAPUDI(06)
# 3       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GAJJANAPUDI(06)
# 4       ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)     CHINTALURU(10)
# ...                ...                ...             ...                ...
# 550237           ASSAM             JORHAT       KALIAPANI     CHINTAMONIGARH
# 550238           ASSAM             JORHAT       KALIAPANI     CHINTAMONIGARH
# 550239           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
# 550240           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
# 550241           ASSAM             JORHAT       KALIAPANI  TAMULICHIGA  GAON
#
# ...

# %%
df2.head()
# Out:
#        State Name      District Name      Block Name   Panchayat Name  \
# 0  ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GOKAVARAM(04)
# 1  ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)    GOKAVARAM(04)
# 2  ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)  GAJJANAPUDI(06)
# 3  ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)  GAJJANAPUDI(06)
# 4  ANDHRA PRADESH  EAST GODAVARI(04)  PRATHIPADU(10)   CHINTALURU(10)
#
#            Village Name                   Habitation Name Quality Parameter  \
# 0        VANTHADA(014 )        VANTHADA(0404410014010400)          Salinity
# 1  PANDAVULAPALEM(022 )  PANDAVULAPALEM(0404410022010400)          Fluoride
# 2      G. KOTHURU(023 )      G. KOTHURU(0404410023010600)          Salinity
# 3     GAJJANAPUDI(029 )     GAJJANAPUDI(0404410029010600)          Salinity
# 4      CHINTALURU(028 )      CHINTALURU(0404410028011000)          Salinity
#
#        Year
# 0  1/4/2009
# 1  1/4/2009
# 2  1/4/2009
# 3  1/4/2009
# 4  1/4/2009

# %%
df2.tail()
# Out:
#        State Name District Name Block Name     Panchayat Name  \
# 550237      ASSAM        JORHAT  KALIAPANI     CHINTAMONIGARH
# 550238      ASSAM        JORHAT  KALIAPANI     CHINTAMONIGARH
# 550239      ASSAM        JORHAT  KALIAPANI  TAMULICHIGA  GAON
# 550240      ASSAM        JORHAT  KALIAPANI  TAMULICHIGA  GAON
# 550241      ASSAM        JORHAT  KALIAPANI  TAMULICHIGA  GAON
#
#                   Village Name                Habitation Name  \
# 550237  GHARACHOWA  HABI  GAON     2 NO. BORA - SAIKIA  CHUCK
# 550238         GHARPHALIA GAON               GHARPHOLIA CHUCK
# 550239         SIMALUGURI GAON      SIMALUGURI  BAMUN   CHUCK
# 550240         SIMALUGURI GAON        POURUA  CHANGMI   CHUCK
# 550241         SIMALUGURI GAON  TATALIGURI    KOIBORTA  CHUCK
#
#        Quality Parameter      Year
# 550237              Iron  1/4/2012
# 550238              Iron  1/4/2012
# 550239              Iron  1/4/2012
# 550240              Iron  1/4/2012
# 550241              Iron  1/4/2012

# %%
q.isnull().sum()
# Out:
# State Name           0
# District Name        0
# Block Name           0
# Panchayat Name       0
# Village Name         0
# Habitation Name      0
# Quality Parameter    0
# Year                 0
# dtype: int64

# %%
r=df2.describe()

# %%
df2.rename(columns={'State Name':'name of the state','District Name':'name of the district','Block Name':'name of the block','Panchayat Name':'name of the panchayat',
           'Village Name':'name of the village','Habitation Name':'name of the habitation',	'Quality Parameter':'Quality parameter','Year':'year'
},inplace=True)
df2
# Out:
#        name of the state name of the district name of the block  \
# 0         ANDHRA PRADESH    EAST GODAVARI(04)    PRATHIPADU(10)
# 1         ANDHRA PRADESH    EAST GODAVARI(04)    PRATHIPADU(10)
# 2         ANDHRA PRADESH    EAST GODAVARI(04)    PRATHIPADU(10)
# 3         ANDHRA PRADESH    EAST GODAVARI(04)    PRATHIPADU(10)
# 4         ANDHRA PRADESH    EAST GODAVARI(04)    PRATHIPADU(10)
# ...                  ...                  ...               ...
# 550237             ASSAM               JORHAT         KALIAPANI
# 550238             ASSAM               JORHAT         KALIAPANI
# 550239             ASSAM               JORHAT         KALIAPANI
# 550240             ASSAM               JORHAT         KALIAPANI
# 550241             ASSAM               JORHAT         KALIAPANI
#
#        name of the panchayat     name of the village  \
# 0              GOKAVARAM(04)          VANTHADA(014 )
# 1              GOKAVARAM(04)    PANDAVULAPALEM(022 )
# ...

# %%
#piechart represents quality parameter 
quality_counts = df2['Quality parameter'].value_counts()
plt.figure(figsize=(10, 8))#pie chart
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('quality parameter')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #piechart represents quality parameter
# ----> 2 quality_counts = df2['Quality parameter'].value_counts()
#       3 plt.figure(figsize=(10, 8))#pie chart
#       4 plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
#
# NameError: name 'df2' is not defined

# %%
#how many quality parameters are present in given data set ,what are they
unique_quality_parameters = df2['Quality parameter'].unique()
num_unique_quality_parameters = len(unique_quality_parameters)

print("Unique Quality Parameters:", unique_quality_parameters)
print("Number of Unique Quality Parameters:", num_unique_quality_parameters)
# Out:
# Unique Quality Parameters: ['Salinity' 'Fluoride' 'Iron' 'Arsenic' '1/4/2009' 'Nitrate' '1/4/2010'
#  nan '1/4/2011' '1/4/2012']
# Number of Unique Quality Parameters: 10

# %%
# Visualization 1: Bar Plot of Quality Parameters
quality_counts = df2['Quality parameter'].value_counts()
plt.figure(figsize=(10, 6))
quality_counts.plot(kind='bar', color='orange')
plt.title('Frequency of Quality Parameters')
plt.xlabel('QualityParameter')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
